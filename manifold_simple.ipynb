# %%
# !pip install gym
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: gym in /home/owen/.local/lib/python3.8/site-packages (0.17.0)
# Requirement already satisfied: scipy in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.6.0)
# Requirement already satisfied: cloudpickle~=1.3.0 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.20.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from gym) (1.14.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# Requirement already satisfied: stable_baselines3 in /home/owen/.local/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: numpy in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.20.0)
# Requirement already satisfied: pandas in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.4.1)
# Requirement already satisfied: matplotlib in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (3.5.1)
# Requirement already satisfied: cloudpickle in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.3.0)
# Requirement already satisfied: gym<0.20,>=0.17 in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (0.17.0)
# Requirement already satisfied: torch>=1.8.1 in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.8.1+cu101)
# Requirement already satisfied: pytz>=2020.1 in /home/owen/.local/lib/python3.8/site-packages (from pandas->stable_baselines3) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/owen/.local/lib/python3.8/site-packages (from pandas->stable_baselines3) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->stable_baselines3) (7.0.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from gym<0.20,>=0.17->stable_baselines3) (1.14.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/owen/.local/lib/python3.8/site-packages (from gym<0.20,>=0.17->stable_baselines3) (1.5.0)
# Requirement already satisfied: scipy in /home/owen/.local/lib/python3.8/site-packages (from gym<0.20,>=0.17->stable_baselines3) (1.6.0)
# Requirement already satisfied: typing-extensions in /home/owen/.local/lib/python3.8/site-packages (from torch>=1.8.1->stable_baselines3) (4.1.1)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<0.20,>=0.17->stable_baselines3) (0.18.2)

# %%
from gym import Env
from gym.spaces import Discrete, Box
import random
import numpy as np
import torch
from stable_baselines3 import SAC, PPO
import gym

# %%
### Define a two line manifold environment ###
class simEnv(Env):
    def __init__(self):
        # Action agent can take
        self.action_space = Discrete(2)
        # Work space
        self.observation_space = Box(np.array([-10, 10]), np.array([-10, 10]))
        # Initial starting point
        self.state = np.array([0, 0])
        # Goal state
        self.goal = np.array([10, 10])
        # Intersection point
        self.intersection = np.array([10, 0])
        # Indicator whether next manifold is reached or not
        self.next_manifold = False
    
    def step(self, action):
        if self.next_manifold:
            if action == 0:
                self.state[1] += 1
            else: 
                self.state[1] -= 1
        else:
            if action == 0:
                self.state[0] += 1
            else: 
                self.state[0] -= 1
        if self.state[0] == 10:
            self.next_manifold = True
        done = False
        # Design rewards
        if self.state[1] != 0 and self.state[0] != 10: # Fall off the manifold
            reward = -100
            done = True
        elif np.array_equal(self.state, self.intersection): # Get to the intersection point
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else:
                reward = 10
        elif np.array_equal(self.state, self.goal): # Reach the goal 
            reward = 100
            done = True
        else: # Direct the agent to intersection point / goal
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 1 / np.linalg.norm(self.state - self.intersection)
        # Set placeholder for info 
        info = {}
        return self.state, reward, done, info
    
    def render(self):
        pass
    
    def reset(self):
        self.state = np.array([0,0])
        self.next_manifold = False
        return self.state

# %%
### Define a two line manifold environment ###
class simEnv1(Env):
    def __init__(self):
        # Action agent can take
        self.action_space = Discrete(4)
        # Work space
        self.observation_space = Box(np.array([-10, 10]), np.array([-10, 10]))
        # Initial starting point
        self.state = np.array([0, 0])
        # Goal state
        self.goal = np.array([10, 10])
        # Intersection point
        self.intersection = np.array([10, 0])
        # Indicator whether next manifold is reached or not
        self.next_manifold = False
    
    def step(self, action):
        # action == 0 => moving up
        if action == 0:
            self.state[1] += 1
        # action == 1 => moving down 
        elif action == 1:
            self.state[1] -= 1
        # action == 2 => moving right
        elif action == 2:
            self.state[0] += 1
        # action == 3 => moving left
        elif action == 3:
            self.state[0] -= 1
        # If action is not valid, error out
        else:
            return
        if self.state[0] == 10:
            self.next_manifold = True
        done = False
        # Design rewards
        if self.state[1] != 0 and self.state[0] != 10: # Fall off the manifold
            reward = -100
            done = True
        elif np.array_equal(self.state, self.intersection): # Get to the intersection point
            reward = 10
        elif np.array_equal(self.state, self.goal): # Reach the goal 
            reward = 100
            done = True
        else: # Direct the agent to intersection point / goal
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 1 / np.linalg.norm(self.state - self.intersection)
        # Set placeholder for info 
        info = {}
        return self.state, reward, done, info
    
    def render(self):
        pass
    
    def reset(self):
        self.state = np.array([0,0])
        self.next_manifold = False
        return self.state

# %%
### Define a two line manifold environment ###
class simEnv2(Env):
    def __init__(self):
        # Action agent can take
        self.action_space = Discrete(4)
        # Work space
        self.observation_space = Box(np.array([-10, 10]), np.array([-10, 10]))
        # Initial starting point
        self.state = np.array([0, 0])
        # Goal state
        self.goal = np.array([10, 10])
        # Intersection point
        self.intersection = np.array([10, 0])
        # Indicator whether next manifold is reached or not
        self.next_manifold = False
    
    def step(self, action):
        # action == 0 => moving up
        if action == 0:
            self.state[1] += 1
        # action == 1 => moving down 
        elif action == 1:
            self.state[1] -= 1
        # action == 2 => moving right
        elif action == 2:
            self.state[0] += 1
        # action == 3 => moving left
        elif action == 3:
            self.state[0] -= 1
        # If action is not valid, error out
        else:
            return
        if self.state[0] == 10:
            self.next_manifold = True
        done = False
        # Design rewards
        if self.next_manifold and self.state[0] != 10: # After reaching the intersection,/
                                                       # discourge of going back to previous manifold
            reward = -100
            done = True 
        elif self.state[1] != 0 and self.state[0] != 10: # Fall off the manifold
            reward = -100
            done = True
        elif np.array_equal(self.state, self.intersection): # Get to the intersection point
            reward = 10
        elif np.array_equal(self.state, self.goal): # Reach the goal 
            reward = 100
            done = True
        else: # Direct the agent to intersection point / goal
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 1 / np.linalg.norm(self.state - self.intersection)
        # Set placeholder for info 
        info = {}
        return self.state, reward, done, info
    
    def render(self):
        pass
    
    def reset(self):
        self.state = np.array([0,0])
        self.next_manifold = False
        return self.state

# %%
### Define a two line manifold environment ### ### With simplified Action Space ###
class simEnv3(Env):
    def __init__(self):
        # Action agent can take
        self.action_space = Discrete(2)
        # Work space
        self.observation_space = Box(np.array([-10, 10]), np.array([-10, 10]))
        # Initial starting point
        self.state = np.array([0, 0])
        # Goal state
        self.goal = np.array([10, 10])
        # Intersection point
        self.intersection = np.array([10, 0])
        # Indicator whether next manifold is reached or not
        self.next_manifold = False
    
    def step(self, action):
        if self.next_manifold:
            if action == 0:
                self.state[1] += 1
            else: 
                self.state[1] -= 1
        else:
            if action == 0:
                self.state[0] += 1
            else: 
                self.state[0] -= 1
        if self.state[0] == 10:
            self.next_manifold = True
        done = False
        # Design rewards
        if self.state[1] != 0 and self.state[0] != 10: # Fall off the manifold
            reward = -100
            done = True
        elif np.array_equal(self.state, self.intersection): # Get to the intersection point
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else:
                reward = 10
        elif np.array_equal(self.state, self.goal): # Reach the goal 
            reward = 100
            done = True
        else: # Direct the agent to intersection point / goal
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 1 / np.linalg.norm(self.state - self.intersection)
        # Set placeholder for info 
        info = {}
        return self.state, reward, done, info
    
    def render(self):
        pass
    
    def reset(self):
        self.state = np.array([0,0])
        self.next_manifold = False
        return self.state

# %%
env = simEnv()

# %%
device = torch.device(
        "cuda:0") if torch.cuda.is_available() else torch.device("cpu")
model = PPO('MlpPolicy', env, verbose=1, device=device)
model = model.learn(total_timesteps=500000, eval_freq=1000)
# Out:
# Using cuda:0 device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1411 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016478904 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0615      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 0.203       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 662          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 809          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0007184186 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.681       |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.81         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000874    |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 662          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 795          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0029714713 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0.28         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00117     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | 0.000823     |
# |    value_loss           | 0.000709     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 662          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0015631944 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.691       |
# |    explained_variance   | 0.00156      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00159     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 0.000143     |
# |    value_loss           | 0.000362     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.004878336 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00035     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0163      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000346    |
# |    value_loss           | 0.000213    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 782         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013060352 |
# |    clip_fraction        | 0.0721      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 2.6e-05     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0153     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00277    |
# |    value_loss           | 0.000206    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 662        |
# |    ep_rew_mean          | 145        |
# | time/                   |            |
# |    fps                  | 781        |
# |    iterations           | 8          |
# |    time_elapsed         | 20         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01735308 |
# |    clip_fraction        | 0.0473     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.688     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0272    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00242   |
# |    value_loss           | 0.000125   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 9           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014782064 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.652      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0177     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 7.18e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 779         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009460616 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.00272     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00233     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000738   |
# |    value_loss           | 7.66e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 662         |
# |    ep_rew_mean          | 145         |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 11          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010329092 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.593      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.527       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 1.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69e+03    |
# |    ep_rew_mean          | 173         |
# | time/                   |             |
# |    fps                  | 777         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021416098 |
# |    clip_fraction        | 0.544       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.519       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0334     |
# |    value_loss           | 1.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 739         |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 13          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015745629 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.2        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 387         |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 776         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015672542 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 544         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 774         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014460212 |
# |    clip_fraction        | 0.0913      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 230         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 518         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 16           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0057372684 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.828        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 154          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 406          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 773          |
# |    iterations           | 17           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0013881349 |
# |    clip_fraction        | 0.0805       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.648       |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.259        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000507     |
# |    value_loss           | 1.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 18          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005669781 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 1.07e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0168      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00115     |
# |    value_loss           | 0.691       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 19          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011737616 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.616      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0186     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00421    |
# |    value_loss           | 0.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 20          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006038632 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.634      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0204      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 6.92e-05    |
# |    value_loss           | 0.335       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 21          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.011078905 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0216      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.000211    |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 771         |
# |    iterations           | 22          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005246293 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.644      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00688    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -2.05e-05   |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 23          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010931617 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.671      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0194      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.0989      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 24          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009360958 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0075     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.000373    |
# |    value_loss           | 0.0666      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 25          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013284117 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0182     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.000647    |
# |    value_loss           | 0.0386      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 26           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0148025425 |
# |    clip_fraction        | 0.0556       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.68        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0136      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000823    |
# |    value_loss           | 0.0286       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 27           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0004357331 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0053       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | 0.000564     |
# |    value_loss           | 0.0228       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 28          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015890336 |
# |    clip_fraction        | 0.0962      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00106    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 29           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0012864923 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000175    |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000437    |
# |    value_loss           | 0.00939      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 770         |
# |    iterations           | 30          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016907543 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 0.00579     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 770          |
# |    iterations           | 31           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0010569212 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00208     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.000417     |
# |    value_loss           | 0.0045       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 769         |
# |    iterations           | 32          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.016480818 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0191     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 0.00328     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 769        |
# |    iterations           | 33         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.01207879 |
# |    clip_fraction        | 0.137      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.692     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0169    |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0018    |
# |    value_loss           | 0.00146    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 768         |
# |    iterations           | 34          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.012289753 |
# |    clip_fraction        | 0.0136      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0235      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000346   |
# |    value_loss           | 0.0012      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 764         |
# |    iterations           | 35          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.016961759 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0392      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000576   |
# |    value_loss           | 0.00196     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 759        |
# |    iterations           | 36         |
# |    time_elapsed         | 97         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01599903 |
# |    clip_fraction        | 0.0256     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.676     |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0211    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.000663  |
# |    value_loss           | 0.00207    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 759          |
# |    iterations           | 37           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0113496985 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0176      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -4.77e-05    |
# |    value_loss           | 0.00061      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 759        |
# |    iterations           | 38         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01842783 |
# |    clip_fraction        | 0.0191     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.684     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0147    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -3.08e-05  |
# |    value_loss           | 0.000278   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 39          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.006333821 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0189      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000103   |
# |    value_loss           | 0.00158     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 40          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.015473493 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0229     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.000141   |
# |    value_loss           | 0.000488    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 41          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006879686 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0279      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000579    |
# |    value_loss           | 0.000347    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 42          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.002967186 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.692      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00524     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000511    |
# |    value_loss           | 0.000244    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 43          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.018570902 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0214      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00324    |
# |    value_loss           | 0.000318    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 760         |
# |    iterations           | 44          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014363145 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0162      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 0.000736    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 760          |
# |    iterations           | 45           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0076119853 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.613       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0175      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000302    |
# |    value_loss           | 0.000144     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 46          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006531993 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 3.1e-05     |
# |    value_loss           | 0.000421    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 47          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007942737 |
# |    clip_fraction        | 0.076       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.017      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 0.000421    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 48          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.010710205 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.022       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 0.000126    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 761         |
# |    iterations           | 49          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.012639201 |
# |    clip_fraction        | 0.0209      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0296      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -1.13e-06   |
# |    value_loss           | 0.000536    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 758        |
# |    iterations           | 50         |
# |    time_elapsed         | 134        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01487506 |
# |    clip_fraction        | 0.0768     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.692     |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.018     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00219   |
# |    value_loss           | 0.000602   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 758          |
# |    iterations           | 51           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0010993681 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00382      |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.000635     |
# |    value_loss           | 1.39e-05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 52.7         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 52           |
# |    time_elapsed         | 140          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0015168998 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00762      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.000608     |
# |    value_loss           | 0.00014      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 52.7       |
# |    ep_rew_mean          | 113        |
# | time/                   |            |
# |    fps                  | 757        |
# |    iterations           | 53         |
# |    time_elapsed         | 143        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.01022864 |
# |    clip_fraction        | 0.0615     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.687     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00415    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.00191   |
# |    value_loss           | 0.0003     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 52.7        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 54          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.009425117 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.003       |
# |    n_updates            | 530         |
# |    policy_gradient_loss | 0.000349    |
# |    value_loss           | 0.000668    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 52.7          |
# |    ep_rew_mean          | 113           |
# | time/                   |               |
# |    fps                  | 756           |
# |    iterations           | 55            |
# |    time_elapsed         | 148           |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 0.00016044648 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.676        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00062       |
# |    n_updates            | 540           |
# ...
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 227       |
# |    time_elapsed         | 624       |
# |    total_timesteps      | 464896    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000141 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.71e-07  |
# |    n_updates            | 2260      |
# |    policy_gradient_loss | 6.75e-06  |
# |    value_loss           | 4.71e-06  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 52.7          |
# |    ep_rew_mean          | 113           |
# | time/                   |               |
# |    fps                  | 744           |
# |    iterations           | 228           |
# |    time_elapsed         | 627           |
# |    total_timesteps      | 466944        |
# | train/                  |               |
# |    approx_kl            | 0.00016472608 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000262     |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.63e-06      |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -1.39e-05     |
# |    value_loss           | 8.12e-06      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 229       |
# |    time_elapsed         | 630       |
# |    total_timesteps      | 468992    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -2.25e-07 |
# |    n_updates            | 2280      |
# |    policy_gradient_loss | -2.44e-06 |
# |    value_loss           | 1.17e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 230       |
# |    time_elapsed         | 633       |
# |    total_timesteps      | 471040    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -2.45e-07 |
# |    n_updates            | 2290      |
# |    policy_gradient_loss | 2.15e-06  |
# |    value_loss           | 7.8e-06   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 231       |
# |    time_elapsed         | 636       |
# |    total_timesteps      | 473088    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.23e-06  |
# |    n_updates            | 2300      |
# |    policy_gradient_loss | 1.92e-07  |
# |    value_loss           | 6.88e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 232       |
# |    time_elapsed         | 639       |
# |    total_timesteps      | 475136    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.29e-05  |
# |    n_updates            | 2310      |
# |    policy_gradient_loss | 7.11e-08  |
# |    value_loss           | 7.06e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 233       |
# |    time_elapsed         | 641       |
# |    total_timesteps      | 477184    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.28e-07 |
# |    n_updates            | 2320      |
# |    policy_gradient_loss | 5.05e-07  |
# |    value_loss           | 6.32e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 743       |
# |    iterations           | 234       |
# |    time_elapsed         | 644       |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.01e-06  |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | 4.13e-08  |
# |    value_loss           | 1.66e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 235       |
# |    time_elapsed         | 646       |
# |    total_timesteps      | 481280    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -2.93e-07 |
# |    n_updates            | 2340      |
# |    policy_gradient_loss | -1.41e-07 |
# |    value_loss           | 1.87e-07  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 236       |
# |    time_elapsed         | 649       |
# |    total_timesteps      | 483328    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.64e-08  |
# |    n_updates            | 2350      |
# |    policy_gradient_loss | -1.04e-06 |
# |    value_loss           | 7.99e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 744       |
# |    iterations           | 237       |
# |    time_elapsed         | 651       |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.14e-05  |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | -7.87e-08 |
# |    value_loss           | 6.18e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 238       |
# |    time_elapsed         | 654       |
# |    total_timesteps      | 487424    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0003    |
# |    loss                 | -1.47e-08 |
# |    n_updates            | 2370      |
# |    policy_gradient_loss | 3.01e-07  |
# |    value_loss           | 9.28e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 239       |
# |    time_elapsed         | 656       |
# |    total_timesteps      | 489472    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.06e-06  |
# |    n_updates            | 2380      |
# |    policy_gradient_loss | -5.54e-07 |
# |    value_loss           | 4.82e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 240       |
# |    time_elapsed         | 659       |
# |    total_timesteps      | 491520    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -4.05e-05 |
# |    n_updates            | 2390      |
# |    policy_gradient_loss | -1.46e-06 |
# |    value_loss           | 9.58e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 745       |
# |    iterations           | 241       |
# |    time_elapsed         | 661       |
# |    total_timesteps      | 493568    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000273 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.77e-05  |
# |    n_updates            | 2400      |
# |    policy_gradient_loss | 5.72e-07  |
# |    value_loss           | 6.16e-06  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 52.7          |
# |    ep_rew_mean          | 113           |
# | time/                   |               |
# |    fps                  | 746           |
# |    iterations           | 242           |
# |    time_elapsed         | 664           |
# |    total_timesteps      | 495616        |
# | train/                  |               |
# |    approx_kl            | 0.00012760758 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000136     |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.59e-06      |
# |    n_updates            | 2410          |
# |    policy_gradient_loss | -1.82e-05     |
# |    value_loss           | 5.71e-06      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 746       |
# |    iterations           | 243       |
# |    time_elapsed         | 666       |
# |    total_timesteps      | 497664    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000128 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.22e-07  |
# |    n_updates            | 2420      |
# |    policy_gradient_loss | 5.67e-07  |
# |    value_loss           | 9.53e-06  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 746       |
# |    iterations           | 244       |
# |    time_elapsed         | 669       |
# |    total_timesteps      | 499712    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000128 |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0003    |
# |    loss                 | -9.69e-07 |
# |    n_updates            | 2430      |
# |    policy_gradient_loss | -1.6e-06  |
# |    value_loss           | 5.1e-06   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 52.7      |
# |    ep_rew_mean          | 113       |
# | time/                   |           |
# |    fps                  | 746       |
# |    iterations           | 245       |
# |    time_elapsed         | 671       |
# |    total_timesteps      | 501760    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000128 |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.38e-05  |
# |    n_updates            | 2440      |
# |    policy_gradient_loss | 4.08e-08  |
# |    value_loss           | 6.96e-06  |
# ---------------------------------------

# %%
obs = env.reset()
print(env)

for _ in range(100):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(obs)
    print(rewards)
# Out:
# <simEnv instance>
# [1 0]
# 0.1111111111111111
# [2 0]
# 0.125
# [3 0]
# 0.14285714285714285
# [4 0]
# 0.16666666666666666
# [5 0]
# 0.2
# [6 0]
# 0.25
# [7 0]
# 0.3333333333333333
# [8 0]
# 0.5
# [9 0]
# 1.0
# [10  0]
# 0.1
# [10  1]
# 0.1111111111111111
# [10  2]
# 0.125
# [10  3]
# 0.14285714285714285
# [10  4]
# 0.16666666666666666
# [10  5]
# 0.2
# [10  6]
# 0.25
# [10  7]
# 0.3333333333333333
# [10  8]
# 0.5
# [10  9]
# 1.0
# [10 10]
# 100
# [10 11]
# 1.0
# [10 12]
# 0.5
# [10 13]
# 0.3333333333333333
# [10 14]
# 0.25
# [10 15]
# 0.2
# [10 16]
# 0.16666666666666666
# [10 17]
# 0.14285714285714285
# [10 18]
# 0.125
# [10 19]
# 0.1111111111111111
# [10 20]
# 0.1
# [10 21]
# 0.09090909090909091
# [10 22]
# 0.08333333333333333
# [10 23]
# 0.07692307692307693
# [10 24]
# 0.07142857142857142
# [10 25]
# 0.06666666666666667
# [10 26]
# 0.0625
# [10 27]
# 0.058823529411764705
# [10 28]
# 0.05555555555555555
# [10 29]
# 0.05263157894736842
# [10 30]
# 0.05
# [10 31]
# 0.047619047619047616
# [10 32]
# 0.045454545454545456
# [10 33]
# 0.043478260869565216
# [10 34]
# 0.041666666666666664
# [10 35]
# 0.04
# [10 36]
# 0.038461538461538464
# [10 37]
# 0.037037037037037035
# [10 38]
# 0.03571428571428571
# [10 39]
# 0.034482758620689655
# [10 40]
# 0.03333333333333333
# [10 41]
# 0.03225806451612903
# [10 42]
# 0.03125
# [10 43]
# 0.030303030303030304
# [10 44]
# 0.029411764705882353
# [10 45]
# 0.02857142857142857
# [10 46]
# 0.027777777777777776
# [10 47]
# 0.02702702702702703
# [10 48]
# 0.02631578947368421
# [10 49]
# 0.02564102564102564
# [10 50]
# 0.025
# [10 51]
# 0.024390243902439025
# [10 52]
# 0.023809523809523808
# [10 53]
# 0.023255813953488372
# [10 54]
# 0.022727272727272728
# [10 55]
# 0.022222222222222223
# [10 54]
# 0.022727272727272728
# [10 55]
# 0.022222222222222223
# [10 56]
# 0.021739130434782608
# [10 57]
# 0.02127659574468085
# [10 58]
# 0.020833333333333332
# [10 59]
# 0.02040816326530612
# [10 60]
# 0.02
# [10 61]
# 0.0196078431372549
# [10 62]
# 0.019230769230769232
# [10 63]
# 0.018867924528301886
# [10 64]
# 0.018518518518518517
# [10 65]
# 0.01818181818181818
# [10 66]
# 0.017857142857142856
# [10 67]
# 0.017543859649122806
# [10 68]
# 0.017241379310344827
# [10 67]
# 0.017543859649122806
# [10 68]
# 0.017241379310344827
# [10 67]
# 0.017543859649122806
# [10 68]
# 0.017241379310344827
# [10 69]
# 0.01694915254237288
# [10 70]
# 0.016666666666666666
# [10 71]
# 0.01639344262295082
# [10 72]
# 0.016129032258064516
# [10 73]
# 0.015873015873015872
# [10 74]
# 0.015625
# [10 75]
# 0.015384615384615385
# [10 76]
# 0.015151515151515152
# [10 77]
# 0.014925373134328358
# [10 78]
# 0.014705882352941176
# [10 79]
# 0.014492753623188406
# [10 80]
# 0.014285714285714285
# [10 81]
# 0.014084507042253521
# [10 82]
# 0.013888888888888888
# [10 83]
# 0.0136986301369863
# [10 84]
# 0.013513513513513514
