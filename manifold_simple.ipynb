# %%
# !pip install gym
# !pip install stable_baselines3
# Out:
# Requirement already satisfied: gym in /home/owen/.local/lib/python3.8/site-packages (0.17.0)
# Requirement already satisfied: scipy in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.6.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from gym) (1.14.0)
# Requirement already satisfied: cloudpickle~=1.3.0 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.3.0)
# Requirement already satisfied: numpy>=1.10.4 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.20.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/owen/.local/lib/python3.8/site-packages (from gym) (1.5.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym) (0.18.2)
# Requirement already satisfied: stable_baselines3 in /home/owen/.local/lib/python3.8/site-packages (1.4.0)
# Requirement already satisfied: cloudpickle in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.3.0)
# Requirement already satisfied: pandas in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.4.1)
# Requirement already satisfied: torch>=1.8.1 in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.8.1+cu101)
# Requirement already satisfied: matplotlib in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (3.5.1)
# Requirement already satisfied: numpy in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (1.20.0)
# Requirement already satisfied: gym<0.20,>=0.17 in /home/owen/.local/lib/python3.8/site-packages (from stable_baselines3) (0.17.0)
# Requirement already satisfied: pytz>=2020.1 in /home/owen/.local/lib/python3.8/site-packages (from pandas->stable_baselines3) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/owen/.local/lib/python3.8/site-packages (from pandas->stable_baselines3) (2.8.1)
# Requirement already satisfied: typing-extensions in /home/owen/.local/lib/python3.8/site-packages (from torch>=1.8.1->stable_baselines3) (4.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (4.29.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib->stable_baselines3) (7.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/owen/.local/lib/python3.8/site-packages (from matplotlib->stable_baselines3) (1.3.2)
# Requirement already satisfied: scipy in /home/owen/.local/lib/python3.8/site-packages (from gym<0.20,>=0.17->stable_baselines3) (1.6.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /home/owen/.local/lib/python3.8/site-packages (from gym<0.20,>=0.17->stable_baselines3) (1.5.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from gym<0.20,>=0.17->stable_baselines3) (1.14.0)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<0.20,>=0.17->stable_baselines3) (0.18.2)

# %%
from gym import Env
from gym.spaces import Discrete, Box
import random
import numpy as np
import torch
from stable_baselines3 import SAC, PPO
import gym

# %%
### Define a two line manifold environment ###
class simEnv(Env):
    def __init__(self):
        # Action agent can take
        self.action_space = Discrete(4)
        # Work space
        self.observation_space = Box(np.array([-10, 10]), np.array([-10, 10]))
        # Initial starting point
        self.state = np.array([0, 0])
        # Goal state
        self.goal = np.array([10, 10])
        # Intersection point
        self.intersection = np.array([10, 0])
        # Indicator whether next manifold is reached or not
        self.next_manifold = False
    
    def step(self, action):
        # action == 0 => moving up
        if action == 0:
            self.state[1] += 1
        # action == 1 => moving down 
        elif action == 1:
            self.state[1] -= 1
        # action == 2 => moving right
        elif action == 2:
            self.state[0] += 1
        # action == 3 => moving left
        elif action == 3:
            self.state[0] -= 1
        # If action is not valid, error out
        else:
            return
        if self.state[0] == 10:
            self.next_manifold = True
        done = False
        # Design rewards
        if self.state[1] != 0 and self.state[0] != 10: # Fall off the manifold
            reward = -100
        elif np.array_equal(self.state, self.intersection): # Get to the intersection point
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 10
        elif np.array_equal(self.state, self.goal): # Reach the goal 
            reward = 100
            done = True
        else: # Direct the agent to intersection point / goal
            if self.next_manifold:
                reward = 1 / np.linalg.norm(self.state - self.goal)
            else: 
                reward = 1 / np.linalg.norm(self.state - self.intersection)
        # Set placeholder for info 
        info = {}
        return self.state, reward, done, info
    
    def render(self):
        pass
    
    def reset(self):
        self.state = np.array([0,0])
        return self.state

# %%
env = simEnv()

# %%
type(env.action_space.sample())
# Out:
# int

# %%
# Test the environment
episodes = 10
for e in range(episodes):
    state = env.reset()
    done = False
    score = 0
    length = 0
    
    while not done and length < 10:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        length += 1
    print("Episode:{} Score:{}".format(e, score))
# Out:
# Episode:0 Score:-899.8888888888889
# Episode:1 Score:-899.9
# Episode:2 Score:-899.9090909090909
# Episode:3 Score:-1000
# Episode:4 Score:-799.8
# Episode:5 Score:-1000
# Episode:6 Score:-399.5031635031635
# Episode:7 Score:-1000
# Episode:8 Score:-899.9090909090909
# Episode:9 Score:-1000

# %%
device = torch.device(
        "cuda:0") if torch.cuda.is_available() else torch.device("cpu")
model = PPO('MlpPolicy', env, verbose=1, device=device)
model = model.learn(total_timesteps=500000, eval_freq=1000)
# Out:
# Using cuda:0 device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -----------------------------
# | time/              |      |
# |    fps             | 1577 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0055554053 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000883    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+06      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00302     |
# |    value_loss           | 2.54e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 3            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0013993202 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.0143       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 2.68e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1046         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0009023781 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -4.05e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+06     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000588    |
# |    value_loss           | 2.39e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1023        |
# |    iterations           | 5           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005449946 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+06    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 2.42e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1008       |
# |    iterations           | 6          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00915659 |
# |    clip_fraction        | 9.77e-05   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | -8.34e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.32e+06   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00447   |
# |    value_loss           | 2.68e+06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 998          |
# |    iterations           | 7            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0006796079 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.79e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38e+06     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000477    |
# |    value_loss           | 2.74e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 991         |
# |    iterations           | 8           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005409686 |
# |    clip_fraction        | 0.00449     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+06    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 2.54e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 985          |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0022201347 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+06      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 2.45e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 981          |
# |    iterations           | 10           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0046188603 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 2.72e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 11           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0014276721 |
# |    clip_fraction        | 0.00396      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 2.74e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 12          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.009374842 |
# |    clip_fraction        | 0.0213      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+06    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00379    |
# |    value_loss           | 2.73e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 13          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008081218 |
# |    clip_fraction        | 0.057       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+06    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0068     |
# |    value_loss           | 2.59e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 14          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004383552 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+06    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 2.66e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 15          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.002082063 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+06    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000505   |
# |    value_loss           | 2.73e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 967          |
# |    iterations           | 16           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0017753479 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+06     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 2.73e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 17           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0034026494 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 2.73e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 18           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012804494 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000523    |
# |    value_loss           | 2.7e+06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 962          |
# |    iterations           | 19           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0050515584 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+06     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 2.68e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 20           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0018887038 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00254     |
# |    value_loss           | 2.72e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 21           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0029569515 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 2.71e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 22           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0024141942 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000931    |
# |    value_loss           | 2.71e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 23          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004620063 |
# |    clip_fraction        | 0.00376     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.36e+06    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.002      |
# |    value_loss           | 2.7e+06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 24           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0017207661 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 2.7e+06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 25           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0010406678 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 8.94e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000936    |
# |    value_loss           | 2.7e+06      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 26          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.003670428 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+06    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 2.69e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 27           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0021330519 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 5.96e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000799    |
# |    value_loss           | 2.69e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 28           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0032693706 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+06     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 2.69e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 29          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.004841432 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+06    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 2.68e+06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 945        |
# |    iterations           | 30         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00560584 |
# |    clip_fraction        | 0.00229    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 5.96e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35e+06   |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00272   |
# |    value_loss           | 2.68e+06   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 939        |
# |    iterations           | 31         |
# |    time_elapsed         | 67         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00250545 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | 4.17e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.33e+06   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.000506  |
# |    value_loss           | 2.68e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 32          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.001202399 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.000522   |
# |    value_loss           | 2.67e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 922         |
# |    iterations           | 33          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003323275 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.000862   |
# |    value_loss           | 2.67e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 911          |
# |    iterations           | 34           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0042920257 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.33        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+06     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 2.67e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 909          |
# |    iterations           | 35           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0021956656 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 2.66e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 909          |
# |    iterations           | 36           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0002518701 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+06     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00474      |
# |    value_loss           | 2.66e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 909          |
# |    iterations           | 37           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0003322553 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.000383     |
# |    value_loss           | 2.66e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 908          |
# |    iterations           | 38           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0018479599 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+06     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.000976    |
# |    value_loss           | 2.65e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 39          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.001513574 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+06    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000335   |
# |    value_loss           | 2.65e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 902           |
# |    iterations           | 40            |
# |    time_elapsed         | 90            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 0.00051929336 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.32e+06      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -0.000967     |
# |    value_loss           | 2.65e+06      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 897         |
# |    iterations           | 41          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.007188583 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 2.64e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 42           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0013315579 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000536    |
# |    value_loss           | 2.64e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 43           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0004182393 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33e+06     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.000264     |
# |    value_loss           | 2.64e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 44           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0036716722 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+06     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 2.63e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 45           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0054075615 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 2.63e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 46           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0052040117 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 2.63e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 872         |
# |    iterations           | 47          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004845626 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00203    |
# |    value_loss           | 2.62e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 48          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.005879561 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.32e+06    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 2.62e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 49            |
# |    time_elapsed         | 116           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00047379485 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.23         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.3e+06       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -2.37e-05     |
# |    value_loss           | 2.62e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 50           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0018331194 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.23        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+06     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000931    |
# |    value_loss           | 2.61e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 855          |
# |    iterations           | 51           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0005136231 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.27e+06     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000109    |
# |    value_loss           | 2.61e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 855           |
# |    iterations           | 52            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00030544007 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.31e+06      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 0.000115      |
# |    value_loss           | 2.61e+06      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 53          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008737488 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29e+06    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 2.6e+06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 54          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.000563649 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+06    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -9.63e-05   |
# |    value_loss           | 2.6e+06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 55           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0019154472 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 2.6e+06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 56           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0009440225 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+06      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000695    |
# |    value_loss           | 2.59e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 57           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0034705722 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+06     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0018      |
# |    value_loss           | 2.59e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 842           |
# |    iterations           | 58            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 0.00022245993 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+06      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | 8.33e-07      |
# |    value_loss           | 2.59e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 843           |
# |    iterations           | 59            |
# |    time_elapsed         | 143           |
# |    total_timesteps      | 120832        |
# | train/                  |               |
# |    approx_kl            | 0.00020911288 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.3e+06       |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000359     |
# |    value_loss           | 2.58e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 844           |
# |    iterations           | 60            |
# |    time_elapsed         | 145           |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 0.00053688564 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.17         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+06      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.000699     |
# |    value_loss           | 2.58e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 841          |
# |    iterations           | 61           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0016268828 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+06      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000622    |
# |    value_loss           | 2.58e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 62           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0014581308 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.28e+06     |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000642    |
# |    value_loss           | 2.57e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 63          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.008181123 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+06    |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 2.57e+06    |
# -----------------------------------------
# ...
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+06     |
# |    n_updates            | 2240         |
# |    policy_gradient_loss | -0.000772    |
# |    value_loss           | 2.06e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 226          |
# |    time_elapsed         | 538          |
# |    total_timesteps      | 462848       |
# | train/                  |              |
# |    approx_kl            | 0.0025785754 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.692       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+06     |
# |    n_updates            | 2250         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 2.05e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 227         |
# |    time_elapsed         | 540         |
# |    total_timesteps      | 464896      |
# | train/                  |             |
# |    approx_kl            | 0.002436491 |
# |    clip_fraction        | 0.0181      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.743      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.03e+06    |
# |    n_updates            | 2260        |
# |    policy_gradient_loss | -0.00296    |
# |    value_loss           | 2.05e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 228          |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 466944       |
# | train/                  |              |
# |    approx_kl            | 6.939683e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.02e+06     |
# |    n_updates            | 2270         |
# |    policy_gradient_loss | 0.00164      |
# |    value_loss           | 2.05e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 229           |
# |    time_elapsed         | 545           |
# |    total_timesteps      | 468992        |
# | train/                  |               |
# |    approx_kl            | 0.00039345637 |
# |    clip_fraction        | 0.0082        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.803        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+06      |
# |    n_updates            | 2280          |
# |    policy_gradient_loss | 0.00235       |
# |    value_loss           | 2.04e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 230           |
# |    time_elapsed         | 547           |
# |    total_timesteps      | 471040        |
# | train/                  |               |
# |    approx_kl            | 0.00011762729 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.788        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.01e+06      |
# |    n_updates            | 2290          |
# |    policy_gradient_loss | 1.63e-05      |
# |    value_loss           | 2.04e+06      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 231         |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.001130076 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.765      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+06       |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.000951   |
# |    value_loss           | 2.04e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 232           |
# |    time_elapsed         | 552           |
# |    total_timesteps      | 475136        |
# | train/                  |               |
# |    approx_kl            | 0.00074785313 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.754        |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+06      |
# |    n_updates            | 2310          |
# |    policy_gradient_loss | -0.000389     |
# |    value_loss           | 2.04e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 233          |
# |    time_elapsed         | 554          |
# |    total_timesteps      | 477184       |
# | train/                  |              |
# |    approx_kl            | 0.0001744245 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1e+06        |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.000483    |
# |    value_loss           | 2.03e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 234         |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.002219653 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+06    |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.00062    |
# |    value_loss           | 2.03e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 235           |
# |    time_elapsed         | 559           |
# |    total_timesteps      | 481280        |
# | train/                  |               |
# |    approx_kl            | 2.4278444e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.794        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.01e+06      |
# |    n_updates            | 2340          |
# |    policy_gradient_loss | 6.74e-05      |
# |    value_loss           | 2.03e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 236           |
# |    time_elapsed         | 561           |
# |    total_timesteps      | 483328        |
# | train/                  |               |
# |    approx_kl            | 0.00016053612 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.792        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.01e+06      |
# |    n_updates            | 2350          |
# |    policy_gradient_loss | -0.000208     |
# |    value_loss           | 2.02e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 237           |
# |    time_elapsed         | 563           |
# |    total_timesteps      | 485376        |
# | train/                  |               |
# |    approx_kl            | 0.00060650543 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.777        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1e+06         |
# |    n_updates            | 2360          |
# |    policy_gradient_loss | 0.000573      |
# |    value_loss           | 2.02e+06      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 238           |
# |    time_elapsed         | 566           |
# |    total_timesteps      | 487424        |
# | train/                  |               |
# |    approx_kl            | 9.7249926e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.771        |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.02e+06      |
# |    n_updates            | 2370          |
# |    policy_gradient_loss | -1.41e-05     |
# |    value_loss           | 2.02e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 239          |
# |    time_elapsed         | 568          |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0018481083 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+06     |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 2.01e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 240          |
# |    time_elapsed         | 570          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 9.872715e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.741       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+06     |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | 0.000176     |
# |    value_loss           | 2.01e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 241          |
# |    time_elapsed         | 572          |
# |    total_timesteps      | 493568       |
# | train/                  |              |
# |    approx_kl            | 3.305223e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+06     |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | 0.00436      |
# |    value_loss           | 2.01e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 242         |
# |    time_elapsed         | 575         |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.001429955 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.716      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+06    |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.000674   |
# |    value_loss           | 2.01e+06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 861           |
# |    iterations           | 243           |
# |    time_elapsed         | 577           |
# |    total_timesteps      | 497664        |
# | train/                  |               |
# |    approx_kl            | 0.00015163317 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.683        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1e+06         |
# |    n_updates            | 2420          |
# |    policy_gradient_loss | -5.45e-05     |
# |    value_loss           | 2e+06         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 244          |
# |    time_elapsed         | 579          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0003172434 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.671       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.94e+05     |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | 0.00277      |
# |    value_loss           | 2e+06        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 245         |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 501760      |
# | train/                  |             |
# |    approx_kl            | 0.001058206 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.676      |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+06    |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.000364   |
# |    value_loss           | 2e+06       |
# -----------------------------------------

# %%
obs = env.reset()
for _ in range(100):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(obs)
    print(rewards)
# Out:
# [0 1]
# -100
# [1 1]
# -100
# [2 1]
# -100
# [2 2]
# -100
# [1 2]
# -100
# [1 1]
# -100
# [0 1]
# -100
# [1 1]
# -100
# [1 2]
# -100
# [1 1]
# -100
# [1 2]
# -100
# [0 2]
# -100
# [1 2]
# -100
# [0 2]
# -100
# [0 3]
# -100
# [-1  3]
# -100
# [0 3]
# -100
# [0 4]
# -100
# [1 4]
# -100
# [0 4]
# -100
# [1 4]
# -100
# [0 4]
# -100
# [-1  4]
# -100
# [-2  4]
# -100
# [-1  4]
# -100
# [-2  4]
# -100
# [-3  4]
# -100
# [-4  4]
# -100
# [-5  4]
# -100
# [-6  4]
# -100
# [-7  4]
# -100
# [-8  4]
# -100
# [-9  4]
# -100
# [-10   4]
# -100
# [-11   4]
# -100
# [-12   4]
# -100
# [-13   4]
# -100
# [-14   4]
# -100
# [-15   4]
# -100
# [-16   4]
# -100
# [-17   4]
# -100
# [-18   4]
# -100
# [-19   4]
# -100
# [-20   4]
# -100
# [-21   4]
# -100
# [-22   4]
# -100
# [-23   4]
# -100
# [-24   4]
# -100
# [-25   4]
# -100
# [-26   4]
# -100
# [-27   4]
# -100
# [-28   4]
# -100
# [-28   5]
# -100
# [-27   5]
# -100
# [-28   5]
# -100
# [-29   5]
# -100
# [-30   5]
# -100
# [-31   5]
# -100
# [-32   5]
# -100
# [-32   6]
# -100
# [-33   6]
# -100
# [-34   6]
# -100
# [-35   6]
# -100
# [-36   6]
# -100
# [-37   6]
# -100
# [-38   6]
# -100
# [-39   6]
# -100
# [-40   6]
# -100
# [-41   6]
# -100
# [-42   6]
# -100
# [-41   6]
# -100
# [-42   6]
# -100
# [-43   6]
# -100
# [-44   6]
# -100
# [-45   6]
# -100
# [-45   5]
# -100
# [-46   5]
# -100
# [-45   5]
# -100
# [-46   5]
# -100
# [-47   5]
# -100
# [-48   5]
# -100
# [-49   5]
# -100
# [-50   5]
# -100
# [-51   5]
# -100
# [-52   5]
# -100
# [-53   5]
# -100
# [-53   6]
# -100
# [-54   6]
# -100
# [-55   6]
# -100
# [-55   7]
# -100
# [-56   7]
# -100
# [-55   7]
# -100
# [-56   7]
# -100
# [-57   7]
# -100
# [-58   7]
# -100
# [-59   7]
# -100
# [-60   7]
# -100
# [-59   7]
# -100
# [-60   7]
# -100
# [-61   7]
# -100
